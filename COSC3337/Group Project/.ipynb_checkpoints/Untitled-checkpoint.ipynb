# %%
from arcgis.gis import GIS
gis = GIS("home")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\_common.py:92, in _tempfile(reader, suffix, _os_remove)
#      91 try:
# ---> 92     os.write(fd, reader())
#      93     os.close(fd)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\abc.py:371, in Traversable.read_bytes(self)
#     368 """
#     369 Read contents of self as bytes
#     370 """
# --> 371 with self.open('rb') as strm:
#     372     return strm.read()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\importlib\_adapters.py:54, in DegenerateFiles.Path.open(self, mode, *args, **kwargs)
#      53 def open(self, mode='rb', *args, **kwargs):
# ---> 54     raise ValueError()
#
# ValueError:
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# ...
